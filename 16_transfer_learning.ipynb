# %%
# transfer learning feature extruction without data augmentation
''' 
https://colab.research.google.com/drive/1bBZOaxju84i8MHscSRqvpgbh2Lf6F6nN#scrollTo=YFhWKnpvYLA1

'''

# %%
# transfer-learning-feature-extraction(data-augmentation).
'''
https://colab.research.google.com/drive/1_RFjpGoh-HpA7MJNgyPbg2xZYvrKJ2O1#scrollTo=zxAWexQUeOwy

'''

# %%
# transfer learning fine tuning.
'''  
https://colab.research.google.com/drive/1mtzKn7u4uaicf69_Sc-X9dAZLN4nUxqT#scrollTo=qRyssbCEusuQ

'''
