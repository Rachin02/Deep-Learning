# %%
from tensorflow import keras
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.preprocessing import image
import numpy as np

# %%
path = '../Dataset/apple.jpg'
img = image.load_img(path, target_size = (224,224))

# %%
model = ResNet50(weights = 'imagenet')

# %%
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)
x = preprocess_input(img)

# %%
y = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
print('predict = ', decode_predictions(y, top = 5)[0])
# Out:
# predict =  [('n03461385', 'grocery_store', np.float32(0.77496153)), ('n07768694', 'pomegranate', np.float32(0.14776133)), ('n07742313', 'Granny_Smith', np.float32(0.014118799)), ('n07753592', 'banana', np.float32(0.013667505)), ('n03127925', 'crate', np.float32(0.006991952))]
